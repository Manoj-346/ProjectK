# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj-346/Death-Note/blob/main/data_frame_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
dt = pd.read_csv('/content/parota.csv')

# %%
dt
# Out:
#     House No.  Square Feet       Location  Rooms  Flats  Windows Amount ($)
# 0           1         1200       Downtown      3      1        8    250,000
# 1           2         2000  Suburban Area      4      2       10    350,000
# 2           3          950       Lakeside      2      1        6    180,000
# 3           4         1500   Urban Center      3      1        9    280,000
# 4           5         1800        Hilltop      4      2       12    330,000
# ..        ...          ...            ...    ...    ...      ...        ...
# 94         95         1400        Hilltop      3      1        7    240,000
# 95         96         1800       Downtown      4      2       10    320,000
# 96         97         2000  Suburban Area      4      2       11    340,000
# 97         98         2100       Lakeside      4      2       12    350,000
# 98         99         1900   Urban Center      4      1       10    310,000
#
# [99 rows x 7 columns]

# %%
dt.describe()
# Out:
#        House No.  Square Feet      Rooms      Flats    Windows
# count  99.000000    99.000000  99.000000  99.000000  99.000000
# mean   50.000000  1645.454545   3.404040   1.484848   9.666667
# std    28.722813   286.702835   0.727298   0.502314   1.884415
# min     1.000000   950.000000   2.000000   1.000000   6.000000
# 25%    25.500000  1500.000000   3.000000   1.000000   8.000000
# 50%    50.000000  1700.000000   3.000000   1.000000   9.000000
# 75%    74.500000  1825.000000   4.000000   2.000000  11.000000
# max    99.000000  2200.000000   5.000000   2.000000  14.000000

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   House No.    99 non-null     int64
#  1   Square Feet  99 non-null     int64
#  2   Location     99 non-null     object
#  3   Rooms        99 non-null     int64
#  4   Flats        99 non-null     int64
#  5   Windows      99 non-null     int64
#  6   Amount ($)   99 non-null     object
# dtypes: int64(5), object(2)
# memory usage: 5.5+ KB

# %%
dt['Amount ($)'].unique()
# Out:
# array(['250,000', '350,000', '180,000', '280,000', '330,000', '275,000',
#        '240,000', '400,000', '320,000', '200,000', '300,000', '360,000',
#        '230,000', '290,000', '270,000', '310,000', '380,000', '220,000',
#        '260,000', '340,000', '210,000', '390,000', '370,000'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Amount ($)'] = l.fit_transform(dt['Amount ($)'])

# %%
dt['Amount ($)'].unique()
# Out:
# array([ 6, 17,  0, 10, 15,  9,  5, 22, 14,  1, 12, 18,  4, 11,  8, 13, 20,
#         3,  7, 16,  2, 21, 19])

# %%
dt
# Out:
#     House No.  Square Feet       Location  Rooms  Flats  Windows  Amount ($)  \
# 0           1         1200       Downtown      3      1        8           6
# 1           2         2000  Suburban Area      4      2       10          17
# 2           3          950       Lakeside      2      1        6           0
# 3           4         1500   Urban Center      3      1        9          10
# 4           5         1800        Hilltop      4      2       12          15
# ..        ...          ...            ...    ...    ...      ...         ...
# 94         95         1400        Hilltop      3      1        7           5
# 95         96         1800       Downtown      4      2       10          14
# 96         97         2000  Suburban Area      4      2       11          16
# 97         98         2100       Lakeside      4      2       12          17
# 98         99         1900   Urban Center      4      1       10          13
#
#     Species
# 0         6
# 1        17
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = dt .drop(['Amount ($)', 'Location'], axis=1)
y = dt['Amount ($)']

# %%
x
# Out:
#     House No.  Square Feet  Rooms  Flats  Windows  Species
# 0           1         1200      3      1        8        6
# 1           2         2000      4      2       10       17
# 2           3          950      2      1        6        0
# 3           4         1500      3      1        9       10
# 4           5         1800      4      2       12       15
# ..        ...          ...    ...    ...      ...      ...
# 94         95         1400      3      1        7        5
# 95         96         1800      4      2       10       14
# 96         97         2000      4      2       11       16
# 97         98         2100      4      2       12       17
# 98         99         1900      4      1       10       13
#
# [99 rows x 6 columns]

# %%
dt.corr(numeric_only=True)
# Out:
#              House No.  Square Feet     Rooms     Flats   Windows  Amount ($)  \
# House No.     1.000000     0.103281  0.047870  0.128012  0.075410   -0.011686
# Square Feet   0.103281     1.000000  0.862832  0.688576  0.895249    0.955370
# Rooms         0.047870     0.862832  1.000000  0.603478  0.881032    0.913315
# Flats         0.128012     0.688576  0.603478  1.000000  0.733046    0.729667
# Windows       0.075410     0.895249  0.881032  0.733046  1.000000    0.935907
# Amount ($)   -0.011686     0.955370  0.913315  0.729667  0.935907    1.000000
# Species      -0.011686     0.955370  0.913315  0.729667  0.935907    1.000000
#
#               Species
# House No.   -0.011686
# Square Feet  0.955370
# Rooms        0.913315
# Flats        0.729667
# Windows      0.935907
# Amount ($)   1.000000
# Species      1.000000

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.25)

# %%
xtest
# Out:
#     House No.  Square Feet  Rooms  Flats  Windows  Species
# 96         97         2000      4      2       11       16
# 54         55         1600      3      1        8        8
# 63         64         1500      3      1        9        7
# 43         44         1600      3      1        9        8
# 70         71         1600      3      2       10        8
# 49         50         1300      3      1        8        6
# 28         29         2100      5      2       13       20
# 78         79         1500      3      1        8        7
# 71         72         1750      3      2        9       10
# 7           8         2200      5      2       12       22
# 3           4         1500      3      1        9       10
# 48         49         1600      3      1        9        8
# 19         20         1100      2      1        7        3
# 24         25         1500      3      2        9       10
# 0           1         1200      3      1        8        6
# ...

# %%
sns.pairplot(dt, hue='Amount ($)')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest, ypred)
# Out:
# 0.08

# %%
import pickle

# %%
pickle.dump(lr, open('parota.pkl', 'wb'))
